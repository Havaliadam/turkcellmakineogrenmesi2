# %%
import pandas as pd 
import numpy as np
df=pd.read_csv("Advertising.csv")
df=df.iloc[:,1:len(df)]
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.info
# Out:
# <bound method DataFrame.info of         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]>

# %%
import seaborn as sns 

sns.jointplot(x="TV",y="sales",data=df,kind="reg")

# %%
from sklearn.linear_model import LinearRegression

# %%
X=df[["TV"]]

# %%
X.head()
# Out:
#       TV
# 0  230.1
# 1   44.5
# 2   17.2
# 3  151.5
# 4  180.8

# %%
y=df[["sales"]]

# %%
reg=LinearRegression()

# %%
model=reg.fit(X,y)#model kırmak

# %%
model
# Out:
# LinearRegression()

# %%
str(model)
# Out:
# 'LinearRegression()'

# %%
dir(model)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_check_feature_names',
#  '_check_n_features',
#  '_decision_function',
#  '_estimator_type',
#  '_get_default_requests',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_tags',
#  '_more_tags',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_set_intercept',
#  '_validate_data',
#  '_validate_params',
#  'coef_',
#  'copy_X',
# ...

# %%
model.intercept_#b0 degeri
# Out:
# array([7.03259355])

# %%
model.coef_#b1 katasaıy
# Out:
# array([[0.04753664]])

# %%
#rkare 
model.score(X,y)
# Out:
# 0.611875050850071

# %%
##tahmin

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
g = sns.regplot(x=df["TV"], y=df["sales"], ci=None, scatter_kws={"color":"r","s":9})
g.set_title("model denklemi:Sales=7.03+TV*0.05")
g.set_ylabel("satiş sayisi")
g.set_xlabel("tv harcamam")
plt.xlim(-10,310)
plt.ylim(bottom=0)
# Out:
# (0.0, 28.27)

# %%
7.03+0.05*165
# Out:
# 15.280000000000001

# %%
model.predict([[165]])
# Out:
# c:\Users\Acer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[14.87613922]])

# %%
model.intercept_+model.coef_*165
# Out:
# array([[14.87613922]])

# %%
yeni_veri=[[5],[15],[30]]

# %%
model.predict(yeni_veri)
# Out:
# c:\Users\Acer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[7.27027675],
#        [7.74564316],
#        [8.45869276]])

# %% [markdown]
# artıklar ve makine öğrenmesi önemi
# mse:hata kare ortaaa
# rmse hata kare ortalama karekökü

# %%
y.head()
# Out:
#    sales
# 0   22.1
# 1   10.4
# 2    9.3
# 3   18.5
# 4   12.9

# %%
model.predict(X)[0:6]
# Out:
# array([[17.97077451],
#        [ 9.14797405],
#        [ 7.85022376],
#        [14.23439457],
#        [15.62721814],
#        [ 7.44616232]])

# %%
gercek_y=y[0:10]

# %%
tahmin_edinen_y=pd.DataFrame(model.predict(X)[0:10])

# %%
hatalar=pd.concat([gercek_y,tahmin_edinen_y],axis=1)

# %%
hatalar.columns=["gercek_y","tahmin_edinen_y"]

# %%
hatalar
# Out:
#    gercek_y  tahmin_edinen_y
# 0      22.1        17.970775
# 1      10.4         9.147974
# 2       9.3         7.850224
# 3      18.5        14.234395
# 4      12.9        15.627218
# 5       7.2         7.446162
# 6      11.8         9.765950
# 7      13.2        12.746498
# 8       4.8         7.441409
# 9      10.6        16.530414

# %%
hatalar["hata"]=hatalar["gercek_y"]-hatalar["tahmin_edinen_y"]

# %%
hatalar
# Out:
#    gercek_y  tahmin_edinen_y      hata
# 0      22.1        17.970775  4.129225
# 1      10.4         9.147974  1.252026
# 2       9.3         7.850224  1.449776
# 3      18.5        14.234395  4.265605
# 4      12.9        15.627218 -2.727218
# 5       7.2         7.446162 -0.246162
# 6      11.8         9.765950  2.034050
# 7      13.2        12.746498  0.453502
# 8       4.8         7.441409 -2.641409
# 9      10.6        16.530414 -5.930414

# %%
hatalar["hata_kare"]=hatalar["hata"]**2

# %%
hatalar
# Out:
#    gercek_y  tahmin_edinen_y      hata  hata_kare
# 0      22.1        17.970775  4.129225  17.050503
# 1      10.4         9.147974  1.252026   1.567569
# 2       9.3         7.850224  1.449776   2.101851
# 3      18.5        14.234395  4.265605  18.195390
# 4      12.9        15.627218 -2.727218   7.437719
# 5       7.2         7.446162 -0.246162   0.060596
# 6      11.8         9.765950  2.034050   4.137358
# 7      13.2        12.746498  0.453502   0.205664
# 8       4.8         7.441409 -2.641409   6.977040
# 9      10.6        16.530414 -5.930414  35.169814

# %%
np.mean(hatalar["hata_kare"])
# Out:
# 9.290350329638102
